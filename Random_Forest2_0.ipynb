# %% [markdown]
# ## STEP 1. Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install -q xlrd

# %%
 from google.colab import files

# %% [markdown]
# ## STEP 2. Data Import

# %%
files.upload()
# Out:
#      <input type="file" id="files-9df188b8-7560-4e58-9704-3b67670d5325" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9df188b8-7560-4e58-9704-3b67670d5325">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel('data_final.xlsx')

# %%
df.head()
# Out:
#   Company       Date  Average\nprice stock  Close Value Fluctuation  \
# 0   TESLA 2017-12-31               20.9544      20.7567         NaN
# 1   TESLA 2018-12-31               21.1540      22.1867          UP
# 2   TESLA 2019-12-31               18.2354      27.8887          UP
# 3   TESLA 2020-12-31               96.6657     235.2233          UP
# 4   TESLA 2021-12-31              259.9982     352.2600          UP
#
#       Volume  Revenue  Debt/Equity Ratio  Gross profit  EBITDA  Automobile  \
# 0   56658000  11759.0             1.9705        2223.0    95.0           1
# 1   94534500  21461.0             2.0796        4042.0  1672.0           1
# 2  154285500  24578.0             1.7971        4069.0  2085.0           1
# 3  148949700  31536.0             0.5087        6630.0  4316.0           1
# 4   40733700  53823.0             0.2203       13606.0  9434.0           1
#
#    Technology
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
df.drop('Company',axis=1,inplace=True)

# %%
df.drop('Date',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Average\nprice stock  Close Value Fluctuation     Volume  Revenue  \
# 0               20.9544      20.7567         NaN   56658000  11759.0
# 1               21.1540      22.1867          UP   94534500  21461.0
# 2               18.2354      27.8887          UP  154285500  24578.0
# 3               96.6657     235.2233          UP  148949700  31536.0
# 4              259.9982     352.2600          UP   40733700  53823.0
#
#    Debt/Equity Ratio  Gross profit  EBITDA  Automobile  Technology
# 0             1.9705        2223.0    95.0           1           0
# 1             2.0796        4042.0  1672.0           1           0
# 2             1.7971        4069.0  2085.0           1           0
# 3             0.5087        6630.0  4316.0           1           0
# 4             0.2203       13606.0  9434.0           1           0

# %% [markdown]
# ## STEP 3. Data Preparation

# %%
df.isnull()
# Out:
#     Average\nprice stock  Close Value  Fluctuation  Volume  Revenue  \
# 0                  False        False         True   False    False
# 1                  False        False        False   False    False
# 2                  False        False        False   False    False
# 3                  False        False        False   False    False
# 4                  False        False        False   False    False
# ..                   ...          ...          ...     ...      ...
# 91                 False        False        False   False    False
# 92                 False        False        False   False    False
# 93                 False        False        False   False    False
# 94                 False        False        False   False    False
# 95                 False        False        False   False    False
#
#     Debt/Equity Ratio  Gross profit  EBITDA  Automobile  Technology
# 0               False         False   False       False       False
# ...

# %%
df.isnull().sum().sum()
# Out:
# 26

# %%
df.isnull().sum(axis=0)
# Out:
# Average\nprice stock     0
# Close Value              0
# Fluctuation             16
# Volume                   0
# Revenue                  2
# Debt/Equity Ratio        6
# Gross profit             2
# EBITDA                   0
# Automobile               0
# Technology               0
# dtype: int64

# %%
df.dropna(axis=0)
# Out:
#     Average\nprice stock  Close Value Fluctuation      Volume  Revenue  \
# 1                21.1540      22.1867          UP    94534500  21461.0
# 2                18.2354      27.8887          UP   154285500  24578.0
# 3                96.6657     235.2233          UP   148949700  31536.0
# 4               259.9982     352.2600          UP    40733700  53823.0
# 5               263.0931     123.1800        DOWN   157777300  81462.0
# ..                   ...          ...         ...         ...      ...
# 91               42.7627      41.3877          UP  20 490 400  70848.0
# 92               45.9265      54.0945          UP  14 432 900  71965.0
# 93               50.1807      46.1429        DOWN  28 576 800  77867.0
# 94               52.3919      48.9193          UP  16 319 000  79024.0
# 95               37.2532      26.0980        DOWN  31 030 100  63054.0
#
#     Debt/Equity Ratio  Gross profit   EBITDA  Automobile  Technology
# ...

# %%
df.dropna(axis=1)
# Out:
#     Average\nprice stock  Close Value      Volume   EBITDA  Automobile  \
# 0                20.9544      20.7567    56658000     95.0           1
# 1                21.1540      22.1867    94534500   1672.0           1
# 2                18.2354      27.8887   154285500   2085.0           1
# 3                96.6657     235.2233   148949700   4316.0           1
# 4               259.9982     352.2600    40733700   9434.0           1
# ..                   ...          ...         ...      ...         ...
# 91               42.7627      41.3877  20 490 400  32401.0           0
# 92               45.9265      54.0945  14 432 900  32861.0           0
# 93               50.1807      46.1429  28 576 800  35917.0           0
# 94               52.3919      48.9193  16 319 000  31248.0           0
# 95               37.2532      26.0980  31 030 100  15369.0           0
#
#     Technology
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# ...

# %%
df['Revenue'].fillna(value=df['Revenue'].mean())
# Out:
# 0     11759.0
# 1     21461.0
# 2     24578.0
# 3     31536.0
# 4     53823.0
#        ...
# 91    70848.0
# 92    71965.0
# 93    77867.0
# 94    79024.0
# 95    63054.0
# Name: Revenue, Length: 96, dtype: float64

# %%
df['Debt/Equity Ratio'].fillna(value=df['Debt/Equity Ratio'].mean())
# Out:
# 0     1.9705
# 1     2.0796
# 2     1.7971
# 3     0.5087
# 4     0.2203
#        ...
# 91    0.3500
# 92    0.3700
# 93    0.4500
# 94    0.4000
# 95    0.4100
# Name: Debt/Equity Ratio, Length: 96, dtype: float64

# %%
df['Gross profit'].fillna(value=df['Gross profit'].mean())
# Out:
# 0      2223.0
# 1      4042.0
# 2      4069.0
# 3      6630.0
# 4     13606.0
#        ...
# 91    43737.0
# 92    42140.0
# 93    43612.0
# 94    43815.0
# 95    26866.0
# Name: Gross profit, Length: 96, dtype: float64

# %%
df.fillna(value=df.mean(), inplace=True)
# Out:
# <ipython-input-129-e31abf4a8a93>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(value=df.mean(), inplace=True)

# %%
df.dropna(axis=0, inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## STEP 4. Data Transformation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 1 to 95
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Average
# price stock  80 non-null     float64
#  1   Close Value          80 non-null     float64
#  2   Fluctuation          80 non-null     object
#  3   Volume               80 non-null     object
#  4   Revenue              80 non-null     float64
#  5   Debt/Equity Ratio    80 non-null     float64
#  6   Gross profit         80 non-null     float64
#  7   EBITDA               80 non-null     float64
#  8   Automobile           80 non-null     int64
#  9   Technology           80 non-null     int64
# dtypes: float64(6), int64(2), object(2)
# memory usage: 6.9+ KB

# %%
pd.get_dummies(df['Fluctuation']).head()
# Out:
#    DOWN  UP
# 1     0   1
# 2     0   1
# 3     0   1
# 4     0   1
# 5     1   0

# %%
gen = pd.get_dummies(df['Fluctuation'], drop_first=True)

# %%
gen.head()
# Out:
#    UP
# 1   1
# 2   1
# 3   1
# 4   1
# 5   0

# %%
df2 = pd.concat([df, gen], axis=1)
df2.head()
# Out:
#    Average\nprice stock  Close Value Fluctuation     Volume  Revenue  \
# 1               21.1540      22.1867          UP   94534500  21461.0
# 2               18.2354      27.8887          UP  154285500  24578.0
# 3               96.6657     235.2233          UP  148949700  31536.0
# 4              259.9982     352.2600          UP   40733700  53823.0
# 5              263.0931     123.1800        DOWN  157777300  81462.0
#
#    Debt/Equity Ratio  Gross profit   EBITDA  Automobile  Technology  UP
# 1             2.0796        4042.0   1672.0           1           0   1
# 2             1.7971        4069.0   2085.0           1           0   1
# 3             0.5087        6630.0   4316.0           1           0   1
# 4             0.2203       13606.0   9434.0           1           0   1
# 5             0.0681       20853.0  17403.0           1           0   0

# %%
df2.drop('Fluctuation', axis=1, inplace=True)
df2.head()
# Out:
#    Average\nprice stock  Close Value     Volume  Revenue  Debt/Equity Ratio  \
# 1               21.1540      22.1867   94534500  21461.0             2.0796
# 2               18.2354      27.8887  154285500  24578.0             1.7971
# 3               96.6657     235.2233  148949700  31536.0             0.5087
# 4              259.9982     352.2600   40733700  53823.0             0.2203
# 5              263.0931     123.1800  157777300  81462.0             0.0681
#
#    Gross profit   EBITDA  Automobile  Technology  UP
# 1        4042.0   1672.0           1           0   1
# 2        4069.0   2085.0           1           0   1
# 3        6630.0   4316.0           1           0   1
# 4       13606.0   9434.0           1           0   1
# 5       20853.0  17403.0           1           0   0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 1 to 95
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Average
# price stock  80 non-null     float64
#  1   Close Value          80 non-null     float64
#  2   Volume               80 non-null     object
#  3   Revenue              80 non-null     float64
#  4   Debt/Equity Ratio    80 non-null     float64
#  5   Gross profit         80 non-null     float64
#  6   EBITDA               80 non-null     float64
#  7   Automobile           80 non-null     int64
#  8   Technology           80 non-null     int64
#  9   UP                   80 non-null     uint8
# dtypes: float64(6), int64(2), object(1), uint8(1)
# memory usage: 6.3+ KB

# %% [markdown]
# ## STEP 5. Data Splitting

# %%
from sklearn.model_selection import train_test_split

# %%
x = df2.drop('UP',axis=1)
y = df2['UP']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30)

# %% [markdown]
# ## STEP 6. RF Algorithm

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
df['Volume'] = df['Volume'].replace('\u202f', '', regex=True).astype(float)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 1 to 95
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Average
# price stock  80 non-null     float64
#  1   Close Value          80 non-null     float64
#  2   Volume               30 non-null     float64
#  3   Revenue              80 non-null     float64
#  4   Debt/Equity Ratio    80 non-null     float64
#  5   Gross profit         80 non-null     float64
#  6   EBITDA               80 non-null     float64
#  7   Automobile           80 non-null     int64
#  8   Technology           80 non-null     int64
#  9   UP                   80 non-null     uint8
# dtypes: float64(7), int64(2), uint8(1)
# memory usage: 6.3 KB

# %%
print(df['Volume'].unique())
# Out:
# [9.453450e+07 1.542855e+08 1.489497e+08 4.073370e+07 1.577773e+08
#  5.781600e+07 3.607490e+07 4.017650e+07 5.189960e+07 3.923220e+07
#  8.455500e+06 5.160200e+06 1.110130e+07 9.856300e+06 1.180740e+07
#  1.158400e+06 2.705000e+05 3.706000e+05 7.241000e+05 7.974000e+05
#  1.847000e+05 8.970000e+04 1.600000e+05 1.899000e+05 1.687000e+05
#  9.080000e+04 8.720000e+04 2.386800e+06 5.212000e+05 2.081492e+08
#  4.306200e+06 1.477200e+06 2.551400e+06 8.694000e+05 4.211400e+06
#  1.773200e+06 1.018400e+06 9.990000e+05 8.223000e+05 1.027300e+06
#  2.986600e+07 1.923600e+07 2.023800e+07 1.297800e+07 1.919030e+07
#  1.400140e+08 1.008056e+08 9.911660e+07 6.406230e+07 7.703420e+07
#  2.462530e+07 8.953500e+06 1.290040e+07 1.287050e+07 1.958380e+07
#  3.317380e+07 1.836940e+07 2.094210e+07 1.800080e+07 2.193850e+07
#  4.982755e+06 3.777504e+06 3.574255e+06 3.361611e+06 2.857969e+06
#  8.587230e+05 5.496720e+05 6.705030e+05 2.750090e+05 4.136110e+05
# ...

# %%
df['Volume'] = df['Volume'].astype(str).str.replace(r'[^\d]+', '', regex=True).astype(float)

# %%
rf = RandomForestClassifier(n_estimators=100)

# %%
rf.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-185-fc0aeedd5571> in <cell line: 1>()
# ----> 1 rf.fit(x_train, y_train)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     343         if issparse(y):
#     344             raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 345         X, y = self._validate_data(
#     346             X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     347         )
#
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# ...

# %%
y_pred = rf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
print(confusion_matrix(y_test,y_pred))
print('\n')
print(classification_report(y_test,y_pred))
